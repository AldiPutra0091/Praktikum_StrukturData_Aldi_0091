# %%
# Fungsi untuk mengonversi daftar karakter menjadi string
def list_to_string(char_list):
    result_string = ''.join(char_list)
    return result_string

# Contoh penggunaan
V = ['p','r','o','g','r','a','m','m','i','n','g']
hasil = list_to_string(V)

# Menampilkan hasil
print(hasil)
# Out:
# programming
