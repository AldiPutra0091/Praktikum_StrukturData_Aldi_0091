# %%
# Membuat tuple
data_aldi = (1, 2, 3, 'ᛆ',	'𐌁',	'ᛎ', 'ᛑ')

# Mengakses elemen tuple
print("Elemen ke-2:", my_tuple[2])
print("Elemen ke-6:", my_tuple[6])

# Tuple bersifat immutable (tidak dapat diubah)
# my_tuple[0] = 10  # Akan menghasilkan error

# Menampilkan seluruh tuple
print("Seluruh Tuple:", data_aldi)
# Out:
# Elemen ke-2: 3
# Elemen ke-6: ᛑ
# Seluruh Tuple: (1, 2, 3, 'ᛆ', '𐌁', 'ᛎ', 'ᛑ')

# %%
# Membuat dictionary
data_aldi = {'nama': 'Watashi', 'umur': 16, 'kota': 'Depok'}

# Mengakses nilai berdasarkan kunci
print("Nama:", data_aldi['nama'])
print("Umur:", data_aldi['umur'])

# Mengubah nilai berdasarkan kunci
data_aldi['umur'] = 26

# Menambahkan elemen baru
data_aldi['pekerjaan'] = 'Pelajar SMA'

# Menghapus elemen berdasarkan kunci
del data_aldi['kota']

# Menampilkan seluruh dictionary
print("Seluruh Dictionary:", data_aldi)
# Out:
# Nama: Watashi
# Umur: 16
# Seluruh Dictionary: {'nama': 'Watashi', 'umur': 26, 'pekerjaan': 'Pelajar SMA'}
